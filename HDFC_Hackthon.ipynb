# %% [markdown]
# <a href="https://colab.research.google.com/github/krsna540/Hackthons/blob/master/HDFC_Hackthon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # for heatmap plot
# Suppressing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
traindf=pd.read_csv("/content/drive/My Drive/Colab Notebooks/DataSet/Train.csv")
traindf.shape
# Out:
# (17521, 2395)

# %%
traindf.head()
# Out:
#         Col1  Col2          Col3  ...  Col2395  Col2396  Col2397
# 0    RIGHGSN     1  1.086711e+04  ...     22.0     22.0      7.0
# 1  RIMHI5ZGP     0  2.584312e+05  ...     12.0     12.0     11.0
# 2  RIHOG1SZU     0  1.459355e+07  ...     21.0     21.0     16.0
# 3  RIHOLMQWU     0  6.727043e+05  ...    951.0    951.0    743.0
# 4  RIHO584ET     0 -1.218742e+06  ...   2205.0   2205.0   1831.0
#
# [5 rows x 2395 columns]

# %%
traindf.drop('Col1', axis=1, inplace=True)
traindf.rename(columns={'Col2': 'Status'}, inplace=True)

# %%
traindf.head()
# Out:
#    Status          Col3          Col4  ...  Col2395  Col2396  Col2397
# 0       1  1.086711e+04  8.648345e+03  ...     22.0     22.0      7.0
# 1       0  2.584312e+05  2.179633e+05  ...     12.0     12.0     11.0
# 2       0  1.459355e+07  1.260060e+07  ...     21.0     21.0     16.0
# 3       0  6.727043e+05  8.181116e+05  ...    951.0    951.0    743.0
# 4       0 -1.218742e+06 -3.005361e+06  ...   2205.0   2205.0   1831.0
#
# [5 rows x 2394 columns]

# %%
traindf.describe()
# Out:
#              Status          Col3  ...       Col2396       Col2397
# count  17521.000000  1.752100e+04  ...  16347.000000  16335.000000
# mean       0.100508  3.158967e+04  ...     17.539977     10.359657
# std        0.300685  7.612897e+05  ...     24.685954     18.476447
# min        0.000000 -8.555719e+07  ...      0.000000      0.000000
# 25%        0.000000  2.742337e+03  ...      9.000000      5.000000
# 50%        0.000000  9.308060e+03  ...     13.000000      7.000000
# 75%        0.000000  3.053873e+04  ...     21.000000     12.000000
# max        1.000000  1.459355e+07  ...   2205.000000   1831.000000
#
# [8 rows x 2392 columns]

# %%
traindf.isnull().any().sum()
# Out:
# 759

# %%
# distribution of Amount
amount = [traindf['Status'].values]
sns.distplot(amount)

# %%
traindf.fillna(0, inplace=True)

# %%
traindf.isnull().any().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()

# %%
traindf.iloc[:,1:]
# Out:
#                Col3          Col4          Col5  ...  Col2395  Col2396  Col2397
# 0      1.086711e+04  8.648345e+03  1.576618e+04  ...     22.0     22.0      7.0
# 1      2.584312e+05  2.179633e+05  1.866287e+05  ...     12.0     12.0     11.0
# 2      1.459355e+07  1.260060e+07  1.100315e+07  ...     21.0     21.0     16.0
# 3      6.727043e+05  8.181116e+05  6.794893e+05  ...    951.0    951.0    743.0
# 4     -1.218742e+06 -3.005361e+06 -1.666241e+05  ...   2205.0   2205.0   1831.0
# 5      3.911176e+06  3.911176e+06  2.995007e+06  ...     20.0     20.0     18.0
# 6      1.173942e+05  8.499665e+04  8.499665e+04  ...      9.0      9.0      4.0
# 7      2.582386e+05  2.101529e+05  2.104294e+05  ...     18.0     15.0      5.0
# 8      1.463930e+04  1.581304e+04  1.928101e+04  ...     12.0     12.0      6.0
# 9      8.405841e+04  3.268636e+04  3.268636e+04  ...     10.0      9.0      4.0
# 10     8.331730e+04  3.398408e+04  3.469404e+04  ...      8.0      8.0      4.0
# ...
